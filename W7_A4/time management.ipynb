# %%
import pandas as pd
import numpy as np

# %%
grades = pd.read_excel('C:/Users/xinyu/Desktop/6419 data visulation/week 7/Assignment 7/datasets/Gradedata.xlsx')

# %%
grades.head(0)
# Out:
# Empty DataFrame
# Columns: [fname, lname, gender, age, exercise, hours, grade, address]
# Index: []

# %%
grades['timemgmt'] = np.where((grades['exercise']>3)
& (grades['hours'] > 17),'busy', 'not busy')

# %%
grades.head(10)
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
# 5     Neil   Whitley    male   16         5     16   88.7
# 6    Nelle    Golden  female   17         1      9   80.2
# 7  Armando   Hoffman    male   17         5     18   95.1
# 8  Illiana     Rojas  female   15         5      9   76.5
# 9     Neil    Wooten    male   15         3     15   89.7
#
#                                              address  timemgmt
# 0               7379 Highland Rd. , Dublin, GA 31021  not busy
# 1                 8 Bayport St. , Honolulu, HI 96815  not busy
# 2                  Encino, CA 91316, 3 Lilac Street   not busy
# 3         Riverview, FL 33569, 9998 North Smith Dr.   not busy
# ...
